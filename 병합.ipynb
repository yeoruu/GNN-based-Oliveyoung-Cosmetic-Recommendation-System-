# %%
import pandas as pd

files = [
    "table1_essence_reviews200.csv",
    "table1_essence_reviews400.csv",
    "table1_essence_reviews600.csv",
    "table1_essence_reviews800.csv",
    "table1_essence_reviews893.csv",
]

dfs = [pd.read_csv(f) for f in files]

merged_df = pd.concat(dfs, axis=0, ignore_index=True)

merged_df.to_csv("table1_essence_reviews_all.csv", index=False)
